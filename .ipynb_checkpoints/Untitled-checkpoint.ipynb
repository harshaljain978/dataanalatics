# %%
import numpy as np

# %%
list = [[18,70,80],[19,71,72],[20,66,72]]
data = np.array(list)

# %%
print(data)
# Out:
# [[18 70 80]
#  [19 71 72]
#  [20 66 72]]

# %%
data.shape
# Out:
# (3, 3)

# %%
data[:,0].mean()
# Out:
# np.float64(19.0)

# %%
data[:,1].max()
# Out:
# np.int64(71)

# %%
data[data[:,1]>80]
# Out:
# array([], shape=(0, 3), dtype=int64)

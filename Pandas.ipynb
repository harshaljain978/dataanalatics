# %%
import numpy as np
import pandas as pd

# %%
#Series

# %%
list_of_sweets = ["Gulab Jamun","Ras Malai", "waffel"]

# %%
print(list_of_sweets)
# Out:
# ['Gulab Jamun', 'Ras Malai', 'waffel']

# %%
s = pd.Series(list_of_sweets)
print(s)
# Out:
# 0    Gulab Jamun
# 1      Ras Malai
# 2         waffel
# dtype: str

# %%
lable = ["a","b","c"]
s2 = pd.Series(list_of_sweets, index=lable)
print(s2)
# Out:
# a    Gulab Jamun
# b      Ras Malai
# c         waffel
# dtype: str

# %%
arr = [1,2,3,4,5]
s3 = pd.Series(arr)
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#dataframe

# %%
employees = {
"name": ["Harshal","Hariyali","Meenakshi","Nilesh"],
"age": [22,20,50,51],
"city": ["Pune","Udaipur","Udaipur","Pratapgarh"]
}

# %%
employees
# Out:
# {'name': ['Harshal', 'Hariyali', 'Meenakshi', 'Nilesh'],
#  'age': [22, 20, 50, 51],
#  'city': ['Pune', 'Udaipur', 'Udaipur', 'Pratapgarh']}

# %%
df_of_employess = pd.DataFrame(employees)
df_of_employess
# Out:
#         name  age        city
# 0    Harshal   22        Pune
# 1   Hariyali   20     Udaipur
# 2  Meenakshi   50     Udaipur
# 3     Nilesh   51  Pratapgarh
